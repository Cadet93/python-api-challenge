# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Three Observable trends based on the data:
#
# 1. There is a clear relationship between Max Temperature and Latitude. The data clearly displays an increasing Max Temp as you approach the Equator.
#
# 2. It surprised me that there is not a strong relationship between Humidity and Latitude. I expected Humidity to be similar to Max Temperature.
#
# 3. There is no significant relationship between Latitude and either Cloudiness or Wind Speed. I initially thought that Wind Speed seemed to increase at the poles and the Equator, but the regression does not shop a relationship.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import scipy.stats as st
from scipy.stats import linregress
from datetime import datetime
from pprint import pprint

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#test to see if OpenWeather API key works and I can pull for the OpenWeather API
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"
city = "London"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city

# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
pprint(weather_json)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1594921045,
#  'id': 2643743,
#  'main': {'feels_like': 71.46,
#           'humidity': 56,
#           'pressure': 1020,
#           'temp': 72.81,
#           'temp_max': 73.99,
#           'temp_min': 71.6},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 1414,
#          'sunrise': 1594872145,
#          'sunset': 1594930223,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'speed': 5.82}}

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
print(cities)
# Out:
# ['tampayan', 'bengkulu', 'airai', 'vostok', 'busselton', 'haysville', 'rikitea', 'cape town', 'faanui', 'umzimvubu', 'qaanaaq', 'albany', 'faya', 'warqla', 'hobart', 'ponta do sol', 'mataura', 'nha trang', 'hilo', 'ilulissat', 'pervomayskiy', 'fort nelson', 'luderitz', 'tsihombe', 'dunedin', 'codrington', 'malibu', 'rio grande', 'mys shmidta', 'severo-kurilsk', 'pierre', 'taolanaro', 'rawannawi', 'gamba', 'khatanga', 'palana', 'soyo', 'ponta delgada', 'tumannyy', 'saskylakh', 'lompoc', 'saleaula', 'portland', 'ushuaia', 'butaritari', 'komsomolskiy', 'dosso', 'ye', 'punta arenas', 'hasaki', 'bethel', 'mehamn', 'vaini', 'puerto ayora', 'yellowknife', 'bud', 'feldbach', 'mount gambier', 'hofn', 'panacan', 'lata', 'georgetown', 'saint-pierre', 'jamestown', 'hermanus', 'tuatapere', 'port alfred', 'chuy', 'tasiilaq', 'arraial do cabo', 'hamilton', 'illoqqortoormiut', 'atar', 'nizhneyansk', 'barentsburg', 'castro', 'talnakh', 'kapaa', 'rapid valley', 'pevek', 'santo angelo', 'east london', 'adrar', 'saint-augustin', 'thaba-tseka', 'new norfolk', 'kathmandu', 'amderma', 'mahebourg', 'zabol', 'amapa', 'sitka', 'waipawa', 'tefe', 'byron bay', 'dobson', 'split', 'petropavlovsk-kamchatskiy', 'te anau', 'samarai', 'gat', 'acapulco', 'meyungs', 'yunhe', 'aasiaat', 'victoria', 'mar del plata', 'bluff', 'clyde river', 'chokurdakh', 'barra', 'lebu', 'suda', 'leningradskiy', 'avarua', 'auki', 'bismil', 'morehead', 'vao', 'san juan', 'bambous virieux', 'darab', 'muros', 'kruisfontein', 'sao jose da coroa grande', 'cervo', 'nyurba', 'aklavik', 'bitung', 'koutiala', 'bredasdorp', 'isangel', 'san policarpo', 'oshkosh', 'ashqelon', 'hirara', 'pokhara', 'mitla', 'dalby', 'pyapon', 'aljezur', 'nikolskoye', 'san', 'wanning', 'coroiesti', 'nizhniy kuranakh', 'torbay', 'kodiak', 'barrow', 'garowe', 'mandalgovi', 'iqaluit', 'leshukonskoye', 'taboga', 'borzya', 'bathsheba', 'ballina', 'puerto escondido', 'ribeira grande', 'ambulu', 'yumen', 'stornoway', 'lipetsk', 'verkhnevilyuysk', 'esperance', 'nazca', 'san patricio', 'vardo', 'kuche', 'azangaro', 'manta', 'ruidoso', 'nkhotakota', 'atuona', 'tuktoyaktuk', 'berlevag', 'casas grandes', 'half moon bay', 'figeac', 'santa maria', 'labutta', 'grand haven', 'priladozhskiy', 'sergeyevka', 'okha', 'toliary', 'yushu', 'saint-joseph', 'thompson', 'ibra', 'port hawkesbury', 'svetlogorsk', 'bacabal', 'tiksi', 'idaho falls', 'inhambane', 'santiago de cao', 'berdigestyakh', 'kaitangata', 'klaksvik', 'sola', 'doha', 'opportunity', 'malwan', 'biak', 'vega de alatorre', 'nyuksenitsa', 'hithadhoo', 'amahai', 'catalca', 'mount isa', 'northam', 'saint george', 'saint-georges', 'beaverlodge', 'sri aman', 'saldanha', 'saint-philippe', 'sorland', 'marcona', 'denpasar', 'leopold', 'shasta lake', 'ketchikan', 'maniitsoq', 'samusu', 'mahbubnagar', 'yerbogachen', 'pisco', 'eydhafushi', 'moranbah', 'souillac', 'dikson', 'bandarbeyla', 'rozkishne', 'aragarcas', 'kahuta', 'san severo', 'arlit', 'los llanos de aridane', 'deyang', 'limulunga', 'kargasok', 'port elizabeth', 'kudahuvadhoo', 'taltal', 'taungdwingyi', 'aykhal', 'provideniya', 'governador valadares', 'vaitupu', 'belushya guba', 'buraydah', 'turukhansk', 'nemuro', 'quelimane', 'kaohsiung', 'ankpa', 'dallas', 'temaraia', 'andreapol', 'cochrane', 'shaping', 'requena', 'longyearbyen', 'majene', 'karpathos', 'resavica', 'sentyabrskiy', 'maniwaki', 'neftekamsk', 'shimoda', 'little current', 'sharlyk', 'arzgir', 'tamala', 'yakuplu', 'kamenka', 'atikokan', 'attawapiskat', 'kaduqli', 'asau', 'stabat', 'cidreira', 'saint-michel-des-saints', 'morgaushi', 'mormugao', 'vanimo', 'eucaliptus', 'grand river south east', 'carnarvon', 'marzuq', 'fort saint john', 'san cristobal', 'tecoanapa', 'port-gentil', 'mecca', 'atambua', 'north bend', 'lakes entrance', 'lufilufi', 'gondanglegi', 'ust-kamchatsk', 'korla', 'lolua', 'necochea', 'madison', 'beringovskiy', 'piryion', 'kavieng', 'constitucion', 'grand gaube', 'rocha', 'rungata', 'ancud', 'weligama', 'la palma', 'tanout', 'chkalovskoye', 'noua ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_weather = []

for city in cities:
    
    response = requests.get(url + "appid=" + weather_api_key + "&q=" + city).json()

    response
    
    try:
        
        weather_dict = {"City": response['name'],
                        "Lat": response['coord']['lat'],
                        "Lng": response['coord']['lon'],
                        "Max Temp": response['main']['temp_max'],
                        "Humidity": response['main']['humidity'],
                        "Cloudiness": response['clouds']['all'],
                        "Wind Speed": response['wind']['speed'],
                        "Country": response['sys']['country'],
                        "Date": response['dt']
                        }
                        
    
# City Name: Kayerkan / ID:1497337
# City Name: Kichera / ID:2022129
# City Name: Borovskoy / ID:1525121
# City Name: Tarakan / ID:1624725
# City Name: Port Angeles / ID:5807212
# City Name: Port Hardy / ID:6111862
# City Name: Mount Hagen / ID:2090409
# City Name: Goulburn / ID:2164837
# City Name: Naze / ID:1855540
# City Name: Malaya Serdoba / ID:531383
# City Name: Laguna / ID:5364271
# City Name: Muncar / ID:1634718
# City Name: Imeni Poliny Osipenko / ID:2023584
# City Name: Sankt Pölten / ID:2766429
# City Name: Pochutla / ID:3517970
# City Name: Pacific Grove / ID:5380437
# City Name: Zliten / ID:2208485
# City Name: Grenå / ID:2621230
# Missing city...skipping | louisbourg
# City Name: Kavaratti / ID:1267390
# City Name: Vila / ID:7117100
# City Name: Merauke / ID:2082539
# City Name: Emmett / ID:5592562
# City Name: Carauari / ID:3664659
# City Name: Ust'-Kulom / ID:478050
# City Name: Abu Dhabi / ID:292968
# City Name: Hambantota / ID:1244926
# City Name: Praia da Vitória / ID:3372760
# City Name: Dawlatabad / ID:1142226
# City Name: Idah / ID:2339156
# City Name: Sapele / ID:2323675
# City Name: Shakawe / ID:933077
# City Name: Quatre Cocos / ID:1106643
# City Name: Port Augusta / ID:2063056
# City Name: Ramsar / ID:9874
# City Name: Ahipara / ID:2194098
# City Name: General Pico / ID:3855075
# City Name: Batemans Bay / ID:2176639
# City Name: Shelton / ID:4842898
# City Name: Hoquiam / ID:5797693
# City Name: Urengoy / ID:1488414
# City Name: Suicheng / ID:1793899
# City Name: Hailar / ID:2037078
# City Name: Sayyan / ID:70979
# City Name: Paka / ID:1734313
# City Name: Baiyin / ID:1817240
# City Name: Vizinga / ID:473263
# City Name: Synya / ID:485215
# City Name: Umeå / ID:602150
# City Name: Makakilo City / ID:5850554
# Missing city...skipping | katha
# City Name: Vurnary / ID:470845
# City Name: Namatanai / ID:2090021
# City Name: Rome / ID:5134295
# City Name: Arinos / ID:3471522
# City Name: Kirakira / ID:2178753
# City Name: Lorengau / ID:2092164
# City Name: Lerwick / ID:2644605
# City Name: Sabang / ID:1214026
# Missing city...skipping | jabiru
# City Name: Henties Bay / ID:3356832
# Missing city...skipping | paradwip
# City Name: Krupka / ID:3072598
# City Name: Vredendal / ID:3359736
# City Name: Kieta / ID:2094027
# City Name: Iraray / ID:1710554
# City Name: Opuwo / ID:3354077
# City Name: Kahului / ID:5847411
# City Name: Yurgamysh / ID:1485721
# Missing city...skipping | mataiea

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_df = pd.DataFrame(city_weather)

city_weather_df.to_csv(r'../cities.csv', index=False, header=True)

#convert unix date's to a readable format
#city_weather_df['Date'] = pd.to_datetime(city_weather_df['Date'])

city_weather_df
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Tampayan  12.48  122.52     82.80        77         100        7.43
# 1     Bengkulu  -3.80  102.27     77.58        86          77        3.98
# 2        Airai  -8.93  125.41     57.13       100          33        2.82
# 3       Vostok  46.49  135.88     58.69        94          21        4.18
# 4    Busselton -33.65  115.33     54.00        87          46       10.89
# ..         ...    ...     ...       ...       ...         ...         ...
# 539      Kieta  -6.22  155.63     79.00        80          82        5.77
# 540     Iraray   8.99  118.05     80.35        79          97        6.13
# 541      Opuwo -18.06   13.84     61.14        30           0       11.92
# 542    Kahului  20.89 -156.47     78.80        65          40        8.05
# 543  Yurgamysh  55.37   64.47     71.13        69           0        6.20
#
#     Country        Date
# 0        PH  1594921075
# 1        ID  1594921004
# 2        TL  1594921075
# 3        RU  1594921075
# 4        AU  1594921075
# ..      ...         ...
# 539      PG  1594920842
# 540      PH  1594921140
# 541      NA  1594921140
# 542      US  1594921078
# 543      RU  1594921141
#
# [544 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
# Set length of cities with humidity over 100 to a variable
# .loc finds any rows with Humidity over 100 and returns the length of rows it finds
x = len(city_weather_df.loc[city_weather_df['Humidity'] > 100])

print(x)


if x > 0:
    
    # Make a new DataFrame equal to the city data to drop all humidity outliers by index.
    clean_city_df = city_weather_df[city_weather_df['Humitidy'] > 100]
    
    clean_city_df = clean_city_df.reset_index(drop=True)
    
    # Export the City_Data into a csv
    clean_city_df.to_csv(r'../cities.csv', index=False, header=True)
# Out:
# 0

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a scatter plot which compares latitude and max temperature
current_time = datetime.now()
date = current_time.strftime('%m/%d/%Y')
title_with_date = f'City Latitude vs. Max Temp ({date})'

city_weather_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(8,8),
                  title= title_with_date)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('maxtemp_vs_lat.png', dpi=300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# Observation: The max temperature definitely increases as you approach the Equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#create a scatter plot which compares Latitude and Humidity
title_with_date = f'City Latitude vs. Humidity ({date})'

city_weather_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8),
                  title= title_with_date)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('humidity_vs_lat.png', dpi=300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# Observation: There does not seem to be a strong relationship between Latitude and Windspeed, although wind speed seems to be highter in general at the poles and right at the Equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#create a scatter plot which compares Latitude and Cloudiness
title_with_date = f'City Latitude vs. Cloudiness ({date})'

city_weather_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8),
                  title= title_with_date)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('cloudiness_vs_lat.png', dpi=300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# Observation: the points seem evenly scattered I don't see a relationship between Latitude and Cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#create a scatter plot which compares Latitude and Wind Speed
title_with_date = f'City Latitude vs. Wind Speed ({date})'

city_weather_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8),
                  title= title_with_date)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('windspeed_vs_lat.png', dpi=300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# Observation: The Northern Hemisphere seems to have higher winds in general than the Southern Hemisphere. It could have to do with seasons?

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
#Regimen Quartile, Outlier, Boxplot function
def linear_regression(x_values, y_values, x_label, y_label, line_x, line_y):

    
    #linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(line_x, line_y),fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
#Northern Hemisphere Dataframe
northern_hemisphere_df = city_weather_df.loc[city_weather_df['Lat'] > 0]
#print(northern_hemisphere_df)

southern_hemisphere_df = city_weather_df.loc[city_weather_df['Lat'] < 0]
#print(southern_hemisphere_df)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Tampayan  12.48  122.52     82.80        77         100        7.43
# 3       Vostok  46.49  135.88     58.69        94          21        4.18
# 5    Haysville  37.56  -97.35     75.20        83          75       10.29
# 9      Qaanaaq  77.48  -69.36     44.20        77          66        6.55
# 10      Albany  42.60  -73.97     77.00        59          80        1.01
# ..         ...    ...     ...       ...       ...         ...         ...
# 535     Sabang   5.89   95.32     83.44        74          32        5.64
# 537     Krupka  50.68   13.86     60.01        96           7        1.99
# 540     Iraray   8.99  118.05     80.35        79          97        6.13
# 542    Kahului  20.89 -156.47     78.80        65          40        8.05
# 543  Yurgamysh  55.37   64.47     71.13        69           0        6.20
#
#     Country        Date
# 0        PH  1594921075
# 3        RU  1594921075
# 5        US  1594920845
# 9        GL  1594921076
# 10       US  1594921076
# ..      ...         ...
# 535      ID  1594921140
# 537      CZ  1594921140
# 540      PH  1594921140
# 542      US  1594921078
# 543      RU  1594921141
#
# [379 rows x 9 columns]
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1       Bengkulu  -3.80  102.27     77.58        86          77        3.98
# 2          Airai  -8.93  125.41     57.13       100          33        2.82
# 4      Busselton -33.65  115.33     54.00        87          46       10.89
# 6        Rikitea -23.12 -134.97     73.51        84         100        3.13
# 7      Cape Town -33.93   18.42     55.99        76           0        2.24
# ..           ...    ...     ...       ...       ...         ...         ...
# 533     Lorengau  -2.02  147.27     82.17        70          64        3.06
# 536  Henties Bay -22.12   14.28     65.68        32           0        8.99
# 538    Vredendal -31.67   18.50     62.51        29           0       14.70
# 539        Kieta  -6.22  155.63     79.00        80          82        5.77
# 541        Opuwo -18.06   13.84     61.14        30           0       11.92
#
#     Country        Date
# 1        ID  1594921004
# 2        TL  1594921075
# 4        AU  1594921075
# 6        PF  1594921055
# 7        ZA  1594921075
# ..      ...         ...
# 533      PG  1594921139
# 536      NA  1594921140
# 538      ZA  1594921140
# 539      PG  1594920842
# 541      NA  1594921140
#
# [165 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regression(northern_hemisphere_df['Lat'],northern_hemisphere_df['Max Temp'], 'Latitude', 'Max Temp', 40, 40)
# Out:
# The r-squared is: 0.5756753044201373

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regression(southern_hemisphere_df['Lat'],southern_hemisphere_df['Max Temp'], 'Latitude', 'Max Temp', -30, 40)
# Out:
# The r-squared is: 0.6680354702623563

# %% [markdown]
# Observation on these 2 regressions: There is a strong relationship between Max Temp and Latitude in both the Northern and Southern Hemispheres. Both r values are above .5 + and -.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regression(northern_hemisphere_df['Lat'], northern_hemisphere_df['Humidity'], 'Latitude', 'Humidity', 40, 60)
# Out:
# The r-squared is: 0.015917728547869568

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regression(southern_hemisphere_df['Lat'], southern_hemisphere_df['Humidity'], 'Latitude', 'Humidity', -30, 60)
# Out:
# The r-squared is: 0.00987189695986065

# %% [markdown]
# Observation on these 2 regressions: There is a very minimal relationship between Latitude and Humidity in both Hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regression(northern_hemisphere_df['Lat'],northern_hemisphere_df['Cloudiness'], 'Latitude', 'Cloudiness', 40, 40)
# Out:
# The r-squared is: 0.004100437410854974

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regression(southern_hemisphere_df['Lat'],southern_hemisphere_df['Cloudiness'], 'Latitude', 'Cloudiness', -25, 40)
# Out:
# The r-squared is: 4.240132176083584e-06

# %% [markdown]
# Observation on these 2 regressions: There is not a significant relationship between Latitude and Cloudiness in either hemisphere, but by and even bigger degree in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regression(northern_hemisphere_df['Lat'],northern_hemisphere_df['Wind Speed'], 'Latitude', 'Wind Speed', 45, 15)
# Out:
# The r-squared is: 0.009655557154734998

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regression(southern_hemisphere_df['Lat'],southern_hemisphere_df['Wind Speed'], 'Latitude', 'Wind Speed', -50, 15)
# Out:
# The r-squared is: 0.008190592115342088

# %% [markdown]
# Observation on these 2 regressions: There is a very minimal relationship between Latitude and Wind Speed in both Hemispheres.
