# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint


# Import API key
from config import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#load city weather csv
# Create city weather dataframe and drop any duplicates
city_weather_df = pd.read_csv('../cities.csv')
city_weather_df.dropna(inplace = True)
city_weather_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.80  -68.30     33.80        89           0        4.70
# 1        Bluff -46.60  168.33     38.19        88          50       10.92
# 2       Marzuq  14.40   46.47     85.55        47          88        3.67
# 3       Hobart -42.88  147.33     39.99        86           1        4.27
# 4  Provideniya  64.38 -173.30     53.22        75          81        2.19
#
#   Country        Date
# 0      AR  1594925177
# 1      NZ  1594925348
# 2      YE  1594925413
# 3      AU  1594925412
# 4      RU  1594925413

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# Store latitude and longitude in locations
locations = city_weather_df[["Lat", "Lng"]]

# convert to float
rating = city_weather_df["Humidity"].astype(float)

# Plot Heatmap
fig = gmaps.figure('TERRAIN')

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 )
#set max intensity to 100
heat_layer.max_intensity = 100
heat_layer.point_radius = 5

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#modify datafrome to only include cities with preferred weather conditions
ideal_weather_df = city_weather_df.loc[((city_weather_df["Max Temp"] > 63) & (city_weather_df["Max Temp"] < 75)) &
                                        (city_weather_df["Humidity"] < 60) & (city_weather_df["Wind Speed"] < 12)
                                      ]

print(ideal_weather_df)

ideal_weather_df.dtypes
# Out:
#                  City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 12        Baie-Comeau  49.22  -68.15     68.00        45           1
# 22         Mossamedes -15.20   12.15     69.26        49           0
# 36        Port Alfred -33.59   26.89     57.38        47           0
# 43             Hailey  43.52 -114.32     73.40        38           5
# 65              Hanna  51.63 -111.90     73.99        49          98
# 81             Narsaq  60.92  -46.05     66.20        37          20
# 94        East London -33.02   27.91     58.68        40           0
# 147       Yellowknife  62.46 -114.35     64.99        48          75
# 160         Prymors'k  46.73   36.34     70.95        54         100
# 173          Necochea -38.55  -58.74     57.00        58          11
# 175           Malanje  -9.54   16.34     65.80        27          16
# 177             Yumen  40.28   97.20     71.42        35          90
# 268         Sept-Îles  50.20  -66.38     69.01        45          75
# 270            Viedma -40.81  -63.00     60.01        54           0
# 274           Skuodas  56.27   21.53     69.80        49          27
# 291          Saldanha -33.01   17.94     55.40        58           0
# 296   Haines Junction  60.75 -137.51     66.79        52          31
# 327      Campos Altos -19.70  -46.17     71.33        55           0
# 329       Monchegorsk  67.94   32.87     57.76        56           0
# 336           Shakawe -18.37   21.85     56.48        43           0
# 345           Chicama  -7.84  -79.15     72.12        58           4
# 351            Moyale   3.52   39.06     70.92        58         100
# 365          Toktogul  41.87   72.94     68.70        53          97
# 418            Manono  -7.30   27.42     72.72        34           0
# 426             Csemő  47.12   19.69     69.80        56          97
# 430       Pangnirtung  66.15  -65.71     64.40        52          20
# 446         Līsakovsk  52.54   62.49     72.52        53           0
# 463             Vraca  43.84   18.40     69.80        56          40
# 471        Coromandel -18.47  -47.20     74.01        45          98
# 481        Port Keats -14.25  129.55     63.48        37           0
# 495        Rzhishchëv  49.97   31.05     71.01        52         100
# 506  Villa Carlos Paz -31.42  -64.50     66.99        36           0
# 553          Mosquera   4.71  -74.23     64.40        48          75
# 568   Porto Empedocle  37.29   13.53     73.99        58           0
#
#      Wind Speed Country        Date
# 12         5.82      CA  1594925415
# 22         3.83      AO  1594925173
# 36         6.91      ZA  1594925417
# 43        11.41      US  1594925418
# 65         8.99      CA  1594925230
# 81         3.36      GL  1594925372
# 94         5.32      ZA  1594925423
# 147        4.70      CA  1594925369
# 160        5.79      UA  1594925429
# 173        8.01      AR  1594925430
# 175        3.02      AO  1594925430
# 177        7.09      CN  1594925430
# 268       11.41      CA  1594925400
# 270        4.92      AR  1594925303
# 274        6.93      LT  1594925443
# 291        2.24      ZA  1594925419
# 296        1.48      CA  1594925446
# 327        9.04      BR  1594925450
# 329        6.46      RU  1594925450
# 336        8.30      BW  1594925451
# 345       10.40      PE  1594925451
# 351       11.54      KE  1594925452
# 365        3.78      KG  1594925454
# 418        5.88      CD  1594925459
# 426        9.17      HU  1594925460
# 430        5.82      CA  1594925461
# 446        8.72      KZ  1594925463
# 463        3.36      BA  1594925465
# 471        6.73      BR  1594925465
# 481        6.80      AU  1594925467
# 495        4.47      UA  1594925468
# 506        6.93      AR  1594925470
# 553        6.93      CO  1594925475
# 568       11.18      IT  1594925477
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#create dataframe that will be used to add Nearest Hotel column
hotel_df = ideal_weather_df[["City", "Lat", "Lng", "Country"]].copy()

hotel_df
# Out:
#                  City    Lat     Lng Country
# 12        Baie-Comeau  49.22  -68.15      CA
# 22         Mossamedes -15.20   12.15      AO
# 36        Port Alfred -33.59   26.89      ZA
# 43             Hailey  43.52 -114.32      US
# 65              Hanna  51.63 -111.90      CA
# 81             Narsaq  60.92  -46.05      GL
# 94        East London -33.02   27.91      ZA
# 147       Yellowknife  62.46 -114.35      CA
# 160         Prymors'k  46.73   36.34      UA
# 173          Necochea -38.55  -58.74      AR
# 175           Malanje  -9.54   16.34      AO
# 177             Yumen  40.28   97.20      CN
# 268         Sept-Îles  50.20  -66.38      CA
# 270            Viedma -40.81  -63.00      AR
# 274           Skuodas  56.27   21.53      LT
# 291          Saldanha -33.01   17.94      ZA
# 296   Haines Junction  60.75 -137.51      CA
# 327      Campos Altos -19.70  -46.17      BR
# 329       Monchegorsk  67.94   32.87      RU
# 336           Shakawe -18.37   21.85      BW
# 345           Chicama  -7.84  -79.15      PE
# 351            Moyale   3.52   39.06      KE
# 365          Toktogul  41.87   72.94      KG
# 418            Manono  -7.30   27.42      CD
# 426             Csemő  47.12   19.69      HU
# 430       Pangnirtung  66.15  -65.71      CA
# 446         Līsakovsk  52.54   62.49      KZ
# 463             Vraca  43.84   18.40      BA
# 471        Coromandel -18.47  -47.20      BR
# 481        Port Keats -14.25  129.55      AU
# 495        Rzhishchëv  49.97   31.05      UA
# 506  Villa Carlos Paz -31.42  -64.50      AR
# 553          Mosquera   4.71  -74.23      CO
# 568   Porto Empedocle  37.29   13.53      IT

# %%
#create new column place holder for nearest hotel
hotel_df['Nearest Hotel'] = ""

#find the closest hotel to each set of coordinates
target_radius = 5000
place_type = "lodging"

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {
    "type": place_type,
    "radius": target_radius,
    "key": g_key,
}

# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
    
    lat = row["Lat"]
    lng = row["Lng"]
    
    coords = f'{lat}, {lng}'
    
    # add location to params dict
    params['location'] = coords

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {coords}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    #print out closest hotel name for each set of coordinates and add it to the hotel dataframe
    try:
        print(f"Closest hotel is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Nearest Hotel'] = results[0]['name']
    
    #exception handling for missing hotel names
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")

#drop rows with no hotel from the hotel dataframe
nan_value = float("NaN")
hotel_df.replace("", nan_value, inplace =True)
hotel_df.dropna(subset = ["Nearest Hotel"], inplace = True)
print(hotel_df)
# Out:
# Retrieving Results for Index 12: 49.22, -68.15.
# Closest hotel is Travelodge by Wyndham Baie Comeau.
# ------------
# Retrieving Results for Index 22: -15.2, 12.15.
# Closest hotel is Hotel Chik Chik Namibe.
# ------------
# Retrieving Results for Index 36: -33.59, 26.89.
# Closest hotel is The Halyards Hotel.
# ------------
# Retrieving Results for Index 43: 43.52, -114.32.
# Closest hotel is Wood River Inn & Suites.
# ------------
# Retrieving Results for Index 65: 51.63, -111.9.
# Closest hotel is West View Motel, Hanna, AB.
# ------------
# Retrieving Results for Index 81: 60.92, -46.05.
# Closest hotel is Hotel Narsaq.
# ------------
# Retrieving Results for Index 94: -33.02, 27.91.
# Closest hotel is Tu Casa.
# ------------
# Retrieving Results for Index 147: 62.46, -114.35.
# Closest hotel is The Explorer Hotel.
# ------------
# Retrieving Results for Index 160: 46.73, 36.34.
# Closest hotel is Relax.
# ------------
# Retrieving Results for Index 173: -38.55, -58.74.
# Closest hotel is dyd -mar Hotel.
# ------------
# Retrieving Results for Index 175: -9.54, 16.34.
# Closest hotel is Malanje Hotel.
# ------------
# Retrieving Results for Index 177: 40.28, 97.2.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 268: 50.2, -66.38.
# Closest hotel is Comfort Inn.
# ------------
# Retrieving Results for Index 270: -40.81, -63.0.
# Closest hotel is Hotel Cristal.
# ------------
# Retrieving Results for Index 274: 56.27, 21.53.
# Closest hotel is Skuodiskio uzeiga.
# ------------
# Retrieving Results for Index 291: -33.01, 17.94.
# Closest hotel is Blue Bay Lodge.
# ------------
# Retrieving Results for Index 296: 60.75, -137.51.
# Closest hotel is Parkside Inn.
# ------------
# Retrieving Results for Index 327: -19.7, -46.17.
# Closest hotel is Hotel São José.
# ------------
# Retrieving Results for Index 329: 67.94, 32.87.
# Closest hotel is Laplandiya.
# ------------
# Retrieving Results for Index 336: -18.37, 21.85.
# Closest hotel is Ditlhapi Guest House.
# ------------
# Retrieving Results for Index 345: -7.84, -79.15.
# Closest hotel is Hospedaje Punta Cana PERU.
# ------------
# Retrieving Results for Index 351: 3.52, 39.06.
# Closest hotel is Latahzan guest house.
# ------------
# Retrieving Results for Index 365: 41.87, 72.94.
# Closest hotel is KAGAN.
# ------------
# Retrieving Results for Index 418: -7.3, 27.42.
# Closest hotel is Hotel hewa bora.
# ------------
# Retrieving Results for Index 426: 47.12, 19.69.
# Closest hotel is Istvánfi László.
# ------------
# Retrieving Results for Index 430: 66.15, -65.71.
# Closest hotel is Kilabuk Lodge.
# ------------
# Retrieving Results for Index 446: 52.54, 62.49.
# Closest hotel is Gostinitsa "Kontinent".
# ------------
# Retrieving Results for Index 463: 43.84, 18.4.
# Closest hotel is Hotel Bosnia.
# ------------
# Retrieving Results for Index 471: -18.47, -47.2.
# Closest hotel is Hotel Dona Adélia.
# ------------
# Retrieving Results for Index 481: -14.25, 129.55.
# Closest hotel is TDC Village (Hundred Man Camp).
# ------------
# Retrieving Results for Index 495: 49.97, 31.05.
# Closest hotel is Na Dnipri.
# ------------
# Retrieving Results for Index 506: -31.42, -64.5.
# Closest hotel is Monte Carlo.
# ------------
# Retrieving Results for Index 553: 4.71, -74.23.
# Closest hotel is Hotel SJ.
# ------------
# Retrieving Results for Index 568: 37.29, 13.53.
# Closest hotel is Hotel dei Pini.
# ------------
#                  City    Lat     Lng Country  \
# 12        Baie-Comeau  49.22  -68.15      CA
# 22         Mossamedes -15.20   12.15      AO
# 36        Port Alfred -33.59   26.89      ZA
# 43             Hailey  43.52 -114.32      US
# 65              Hanna  51.63 -111.90      CA
# 81             Narsaq  60.92  -46.05      GL
# 94        East London -33.02   27.91      ZA
# 147       Yellowknife  62.46 -114.35      CA
# 160         Prymors'k  46.73   36.34      UA
# 173          Necochea -38.55  -58.74      AR
# 175           Malanje  -9.54   16.34      AO
# 268         Sept-Îles  50.20  -66.38      CA
# 270            Viedma -40.81  -63.00      AR
# 274           Skuodas  56.27   21.53      LT
# 291          Saldanha -33.01   17.94      ZA
# 296   Haines Junction  60.75 -137.51      CA
# 327      Campos Altos -19.70  -46.17      BR
# 329       Monchegorsk  67.94   32.87      RU
# 336           Shakawe -18.37   21.85      BW
# 345           Chicama  -7.84  -79.15      PE
# 351            Moyale   3.52   39.06      KE
# 365          Toktogul  41.87   72.94      KG
# 418            Manono  -7.30   27.42      CD
# 426             Csemő  47.12   19.69      HU
# 430       Pangnirtung  66.15  -65.71      CA
# 446         Līsakovsk  52.54   62.49      KZ
# 463             Vraca  43.84   18.40      BA
# 471        Coromandel -18.47  -47.20      BR
# 481        Port Keats -14.25  129.55      AU
# 495        Rzhishchëv  49.97   31.05      UA
# 506  Villa Carlos Paz -31.42  -64.50      AR
# 553          Mosquera   4.71  -74.23      CO
# 568   Porto Empedocle  37.29   13.53      IT
#
#                          Nearest Hotel
# 12   Travelodge by Wyndham Baie Comeau
# 22              Hotel Chik Chik Namibe
# 36                  The Halyards Hotel
# 43             Wood River Inn & Suites
# 65          West View Motel, Hanna, AB
# 81                        Hotel Narsaq
# 94                             Tu Casa
# 147                 The Explorer Hotel
# 160                              Relax
# 173                     dyd -mar Hotel
# 175                      Malanje Hotel
# 268                        Comfort Inn
# 270                      Hotel Cristal
# 274                  Skuodiskio uzeiga
# 291                     Blue Bay Lodge
# 296                       Parkside Inn
# 327                     Hotel São José
# 329                         Laplandiya
# 336               Ditlhapi Guest House
# 345          Hospedaje Punta Cana PERU
# 351               Latahzan guest house
# 365                              KAGAN
# 418                    Hotel hewa bora
# 426                    Istvánfi László
# 430                      Kilabuk Lodge
# 446             Gostinitsa "Kontinent"
# 463                       Hotel Bosnia
# 471                  Hotel Dona Adélia
# 481     TDC Village (Hundred Man Camp)
# 495                          Na Dnipri
# 506                        Monte Carlo
# 553                           Hotel SJ
# 568                     Hotel dei Pini

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Nearest Hotel}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig = gmaps.figure()
fig.add_layer(marker_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
